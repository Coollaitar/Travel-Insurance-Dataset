# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
from matplotlib import style
# %matplotlib inline
warnings.filterwarnings('ignore')
# %precision 2
# Out:
# '%.2f'

# %%
df=pd.read_csv('travel insurance.csv')
df.head(6)
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 5    JZI       Airlines               Online                       Value Plan
#
#   Claim  Duration    Destination  Net Sales  Commision (in value) Gender  Age
# 0    No       186       MALAYSIA      -29.0                  9.57      F   81
# 1    No       186       MALAYSIA      -29.0                  9.57      F   71
# 2    No        65      AUSTRALIA      -49.5                 29.70    NaN   32
# 3    No        60      AUSTRALIA      -39.6                 23.76    NaN   32
# ...

# %%
df.isnull().sum()
# Out:
# Agency                      0
# Agency Type                 0
# Distribution Channel        0
# Product Name                0
# Claim                       0
# Duration                    0
# Destination                 0
# Net Sales                   0
# Commision (in value)        0
# Gender                  45107
# Age                         0
# dtype: int64

# %%
df['Gender'].isnull().value_counts()
# Out:
# True     45107
# False    18219
# Name: Gender, dtype: int64

# %%
df.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency                63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df.rename(columns={'Agency':'Agency Name'},inplace = True)
df.head()
# Out:
#   Agency Name    Agency Type Distribution Channel  \
# 0         CBH  Travel Agency              Offline
# 1         CBH  Travel Agency              Offline
# 2         CWT  Travel Agency               Online
# 3         CWT  Travel Agency               Online
# 4         CWT  Travel Agency               Online
#
#                       Product Name Claim  Duration Destination  Net Sales  \
# 0               Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1               Comprehensive Plan    No       186    MALAYSIA      -29.0
# 2  Rental Vehicle Excess Insurance    No        65   AUSTRALIA      -49.5
# 3  Rental Vehicle Excess Insurance    No        60   AUSTRALIA      -39.6
# 4  Rental Vehicle Excess Insurance    No        79       ITALY      -19.8
#
#    Commision (in value) Gender  Age
# 0                  9.57      F   81
# 1                  9.57      F   71
# 2                 29.70    NaN   32
# 3                 23.76    NaN   32
# ...

# %%
df['Agency Name'].nunique()
# Out:
# 16

# %%
df['Agency Name'].value_counts()
# Out:
# EPX    35119
# CWT     8580
# C2B     8267
# JZI     6329
# SSI     1056
# JWT      749
# RAB      725
# LWC      689
# TST      528
# KML      392
# ART      331
# CCR      194
# CBH      101
# TTW       98
# CSR       86
# ADM       82
# Name: Agency Name, dtype: int64

# %%
df['Agency Name'].describe()
# Out:
# count     63326
# unique       16
# top         EPX
# freq      35119
# Name: Agency Name, dtype: object

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='Agency Name',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Name', ylabel='count'>

# %%
df['Agency Type'].nunique()
# Out:
# 2

# %%
df['Agency Type'].value_counts()
# Out:
# Travel Agency    45869
# Airlines         17457
# Name: Agency Type, dtype: int64

# %%
df['Agency Type'].describe()
# Out:
# count             63326
# unique                2
# top       Travel Agency
# freq              45869
# Name: Agency Type, dtype: object

# %%
plt.figure(figsize = (6,5)) 
sns.countplot(x='Agency Type',data = df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Type', ylabel='count'>

# %%
a1=df[df['Agency Type']=='Travel Agency']
a1
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 0             CBH  Travel Agency              Offline
# 1             CBH  Travel Agency              Offline
# 2             CWT  Travel Agency               Online
# 3             CWT  Travel Agency               Online
# 4             CWT  Travel Agency               Online
# ...           ...            ...                  ...
# 63300         EPX  Travel Agency               Online
# 63301         EPX  Travel Agency               Online
# 63302         EPX  Travel Agency               Online
# 63303         EPX  Travel Agency               Online
# 63304         EPX  Travel Agency               Online
#
#                           Product Name Claim  Duration Destination  Net Sales  \
# 0                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 2      Rental Vehicle Excess Insurance    No        65   AUSTRALIA      -49.5
# ...

# %%
a1['Agency Name'].value_counts()
# Out:
# EPX    35119
# CWT     8580
# LWC      689
# TST      528
# KML      392
# CCR      194
# CBH      101
# TTW       98
# CSR       86
# ADM       82
# Name: Agency Name, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Agency Name',data=a1,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Name', ylabel='count'>

# %% [markdown]
# These are the names of Agencies who have 'Travel Agency' type

# %%
a2=df[df['Agency Type']=='Airlines']
a2
# Out:
#       Agency Name Agency Type Distribution Channel Product Name Claim  \
# 5             JZI    Airlines               Online   Value Plan    No
# 10            JZI    Airlines               Online   Basic Plan    No
# 11            JZI    Airlines               Online   Basic Plan    No
# 18            JZI    Airlines               Online   Basic Plan    No
# 21            C2B    Airlines               Online  Bronze Plan    No
# ...           ...         ...                  ...          ...   ...
# 63321         JZI    Airlines               Online   Basic Plan    No
# 63322         JZI    Airlines               Online   Basic Plan    No
# 63323         JZI    Airlines               Online   Basic Plan    No
# 63324         JZI    Airlines               Online   Basic Plan    No
# 63325         JZI    Airlines               Online   Basic Plan    No
#
#        Duration                             Destination  Net Sales  \
# ...

# %%
a2['Agency Name'].value_counts()
# Out:
# C2B    8267
# JZI    6329
# SSI    1056
# JWT     749
# RAB     725
# ART     331
# Name: Agency Name, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Agency Name',data=a2,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Name', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency Name           63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df['Distribution Channel'].value_counts()
# Out:
# Online     62219
# Offline     1107
# Name: Distribution Channel, dtype: int64

# %%
o1=a1[a1['Distribution Channel']=='Online']
o1
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 2             CWT  Travel Agency               Online
# 3             CWT  Travel Agency               Online
# 4             CWT  Travel Agency               Online
# 6             CWT  Travel Agency               Online
# 7             CWT  Travel Agency               Online
# ...           ...            ...                  ...
# 63300         EPX  Travel Agency               Online
# 63301         EPX  Travel Agency               Online
# 63302         EPX  Travel Agency               Online
# 63303         EPX  Travel Agency               Online
# 63304         EPX  Travel Agency               Online
#
#                           Product Name Claim  Duration    Destination  \
# 2      Rental Vehicle Excess Insurance    No        65      AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No        60      AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No        79          ITALY
# ...

# %%
o1['Agency Name'].value_counts()
# Out:
# EPX    35048
# CWT     8573
# LWC      689
# KML      390
# ADM       82
# Name: Agency Name, dtype: int64

# %% [markdown]
# Distribution Channel of Travel Agency companies are maximum Online.

# %%
f1=a1[a1['Distribution Channel']=='Offline']
f1
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 0             CBH  Travel Agency              Offline
# 1             CBH  Travel Agency              Offline
# 400           CSR  Travel Agency              Offline
# 401           CSR  Travel Agency              Offline
# 402           CCR  Travel Agency              Offline
# ...           ...            ...                  ...
# 62949         TST  Travel Agency              Offline
# 62950         TST  Travel Agency              Offline
# 62951         TST  Travel Agency              Offline
# 62952         TST  Travel Agency              Offline
# 63095         EPX  Travel Agency              Offline
#
#                    Product Name Claim  Duration Destination  Net Sales  \
# 0            Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1            Comprehensive Plan    No       186    MALAYSIA      -29.0
# 400          Comprehensive Plan    No        92    MALAYSIA       29.0
# ...

# %%
f1['Agency Name'].value_counts()
# Out:
# TST    528
# CCR    194
# CBH    101
# TTW     98
# CSR     86
# EPX     71
# CWT      7
# KML      2
# Name: Agency Name, dtype: int64

# %% [markdown]
# Agency Named TST has its distribution channel maximum offline and it is also a travel agency.

# %%
o2=a2[a2['Distribution Channel']=='Online']
o2
# Out:
#       Agency Name Agency Type Distribution Channel Product Name Claim  \
# 5             JZI    Airlines               Online   Value Plan    No
# 10            JZI    Airlines               Online   Basic Plan    No
# 11            JZI    Airlines               Online   Basic Plan    No
# 18            JZI    Airlines               Online   Basic Plan    No
# 21            C2B    Airlines               Online  Bronze Plan    No
# ...           ...         ...                  ...          ...   ...
# 63321         JZI    Airlines               Online   Basic Plan    No
# 63322         JZI    Airlines               Online   Basic Plan    No
# 63323         JZI    Airlines               Online   Basic Plan    No
# 63324         JZI    Airlines               Online   Basic Plan    No
# 63325         JZI    Airlines               Online   Basic Plan    No
#
#        Duration                             Destination  Net Sales  \
# ...

# %%
o2['Agency Name'].value_counts()
# Out:
# C2B    8267
# JZI    6324
# SSI    1044
# JWT     749
# RAB     724
# ART     329
# Name: Agency Name, dtype: int64

# %% [markdown]
# Distribution Channel of Airline Agencies are maximum Online.
# Also C2B Agency has its whole distribution channel online.

# %%
f2=a2[a2['Distribution Channel']=='Offline']
f2
# Out:
#       Agency Name Agency Type Distribution Channel      Product Name Claim  \
# 934           SSI    Airlines              Offline  Ticket Protector    No
# 935           SSI    Airlines              Offline  Ticket Protector    No
# 12963         RAB    Airlines              Offline        Value Plan    No
# 17026         SSI    Airlines              Offline  Ticket Protector    No
# 17027         SSI    Airlines              Offline  Ticket Protector    No
# 17028         SSI    Airlines              Offline  Ticket Protector    No
# 17029         SSI    Airlines              Offline  Ticket Protector    No
# 17285         SSI    Airlines              Offline  Ticket Protector    No
# 17286         SSI    Airlines              Offline  Ticket Protector    No
# 17287         SSI    Airlines              Offline  Ticket Protector    No
# 22651         SSI    Airlines              Offline  Ticket Protector    No
# ...

# %%
f2['Agency Name'].value_counts()
# Out:
# SSI    12
# JZI     5
# ART     2
# RAB     1
# Name: Agency Name, dtype: int64

# %% [markdown]
# Very Less number of Airline agencies have their distribution channel offline.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency Name           63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df['Product Name'].nunique()
# Out:
# 26

# %%
df['Product Name'].value_counts()
# Out:
# Cancellation Plan                       18630
# 2 way Comprehensive Plan                13158
# Rental Vehicle Excess Insurance          8580
# Basic Plan                               5469
# Bronze Plan                              4049
# 1 way Comprehensive Plan                 3331
# Value Plan                               2715
# Silver Plan                              2249
# Annual Silver Plan                       1423
# Ticket Protector                         1056
# Travel Cruise Protect                     527
# Comprehensive Plan                        364
# Gold Plan                                 352
# 24 Protect                                247
# Single Trip Travel Protect Gold           204
# Premier Plan                              194
# Annual Gold Plan                          194
# Single Trip Travel Protect Silver         173
# Annual Travel Protect Gold                100
# Annual Travel Protect Silver               86
# ...

# %%
p1=df[df['Product Name']=='Cancellation Plan']
p1
# Out:
#       Agency Name    Agency Type Distribution Channel       Product Name  \
# 60            EPX  Travel Agency               Online  Cancellation Plan
# 61            EPX  Travel Agency               Online  Cancellation Plan
# 62            EPX  Travel Agency               Online  Cancellation Plan
# 63            EPX  Travel Agency               Online  Cancellation Plan
# 64            EPX  Travel Agency               Online  Cancellation Plan
# ...           ...            ...                  ...                ...
# 63292         EPX  Travel Agency               Online  Cancellation Plan
# 63293         EPX  Travel Agency               Online  Cancellation Plan
# 63294         EPX  Travel Agency               Online  Cancellation Plan
# 63295         EPX  Travel Agency               Online  Cancellation Plan
# 63296         EPX  Travel Agency               Online  Cancellation Plan
#
#       Claim  Duration                Destination  Net Sales  \
# ...

# %%
p1['Agency Name'].value_counts()
# Out:
# EPX    18630
# Name: Agency Name, dtype: int64

# %%
epx=df[df['Agency Name']=='EPX']
epx
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 14            EPX  Travel Agency               Online
# 33            EPX  Travel Agency               Online
# 34            EPX  Travel Agency               Online
# 35            EPX  Travel Agency               Online
# 36            EPX  Travel Agency               Online
# ...           ...            ...                  ...
# 63300         EPX  Travel Agency               Online
# 63301         EPX  Travel Agency               Online
# 63302         EPX  Travel Agency               Online
# 63303         EPX  Travel Agency               Online
# 63304         EPX  Travel Agency               Online
#
#                    Product Name Claim  Duration Destination  Net Sales  \
# 14     2 way Comprehensive Plan    No        39    VIET NAM      -25.0
# 33     2 way Comprehensive Plan    No         9   INDONESIA       25.0
# 34     2 way Comprehensive Plan    No        12    MALAYSIA       24.0
# ...

# %%
epx['Product Name'].value_counts()
# Out:
# Cancellation Plan           18630
# 2 way Comprehensive Plan    13158
# 1 way Comprehensive Plan     3331
# Name: Product Name, dtype: int64

# %% [markdown]
# People come to EPX agency for these 3 plans.
# These all 3 plans are Unique and none of the other agency sell those plans.
# Top most selling plans are of EPX agency.

# %%
p2=df[df['Product Name']=='Rental Vehicle Excess Insurance']
p2
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 2             CWT  Travel Agency               Online
# 3             CWT  Travel Agency               Online
# 4             CWT  Travel Agency               Online
# 6             CWT  Travel Agency               Online
# 7             CWT  Travel Agency               Online
# ...           ...            ...                  ...
# 63241         CWT  Travel Agency               Online
# 63242         CWT  Travel Agency               Online
# 63243         CWT  Travel Agency               Online
# 63244         CWT  Travel Agency               Online
# 63245         CWT  Travel Agency               Online
#
#                           Product Name Claim  Duration    Destination  \
# 2      Rental Vehicle Excess Insurance    No        65      AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No        60      AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No        79          ITALY
# ...

# %%
p2['Agency Name'].value_counts()
# Out:
# CWT    8580
# Name: Agency Name, dtype: int64

# %% [markdown]
# Only CWT agency has Rental Vehicle Excess Insurance plan.
#
#
# So in the conclusion we can say that Each Agency has Their Unique Plans or Special plans.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency Name           63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df['Claim'].nunique()
# Out:
# 2

# %%
df['Claim'].value_counts()
# Out:
# No     62399
# Yes      927
# Name: Claim, dtype: int64

# %% [markdown]
# So from above we can see that most of the people did'nt claimed insurance so we can conlude that
# They Did'nt Encounter Any Experience That would force them to claim the said insurance.

# %%
c1=df[df['Claim']=='Yes']
c1
# Out:
#       Agency Name    Agency Type Distribution Channel        Product Name  \
# 23            C2B       Airlines               Online         Bronze Plan
# 248           C2B       Airlines               Online         Silver Plan
# 313           EPX  Travel Agency               Online   Cancellation Plan
# 419           C2B       Airlines               Online         Silver Plan
# 424           C2B       Airlines               Online  Annual Silver Plan
# ...           ...            ...                  ...                 ...
# 63173         EPX  Travel Agency               Online   Cancellation Plan
# 63199         C2B       Airlines               Online         Bronze Plan
# 63206         C2B       Airlines               Online         Bronze Plan
# 63208         C2B       Airlines               Online         Bronze Plan
# 63228         C2B       Airlines               Online  Annual Silver Plan
#
#       Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age
# ...

# %%
c1['Agency Name'].value_counts()
# Out:
# C2B    547
# EPX    195
# CWT     86
# LWC     36
# JZI     31
# KML      8
# SSI      7
# TTW      4
# JWT      4
# CCR      3
# TST      2
# CBH      1
# CSR      1
# RAB      1
# ART      1
# Name: Agency Name, dtype: int64

# %% [markdown]
# Most of the claims are reimbursed by C2B company.

# %%
i1=df[df['Agency Name']=='C2B']
i1
# Out:
#       Agency Name Agency Type Distribution Channel        Product Name Claim  \
# 21            C2B    Airlines               Online         Bronze Plan    No
# 22            C2B    Airlines               Online         Bronze Plan    No
# 23            C2B    Airlines               Online         Bronze Plan   Yes
# 24            C2B    Airlines               Online         Silver Plan    No
# 25            C2B    Airlines               Online  Annual Silver Plan    No
# ...           ...         ...                  ...                 ...   ...
# 63230         C2B    Airlines               Online  Annual Silver Plan    No
# 63231         C2B    Airlines               Online  Annual Silver Plan    No
# 63232         C2B    Airlines               Online    Annual Gold Plan    No
# 63233         C2B    Airlines               Online    Annual Gold Plan    No
# 63234         C2B    Airlines               Online    Annual Gold Plan    No
#
# ...

# %%
i1['Product Name'].value_counts()
# Out:
# Bronze Plan           4049
# Silver Plan           2249
# Annual Silver Plan    1423
# Gold Plan              352
# Annual Gold Plan       194
# Name: Product Name, dtype: int64

# %% [markdown]
# So the Bronze Plan, Silver Plan, Annual Silver Plan are mostly bought by Middle Class people
# whereas Gold Plan and Annual Gold Plan are bought by Rich People like Business community.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency Name           63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Duration

# %%
df['Duration'].value_counts()
# Out:
# 6       2115
# 5       2095
# 7       1970
# 8       1958
# 4       1931
#         ...
# 740        1
# 494        1
# 4652       1
# 4844       1
# 4829       1
# Name: Duration, Length: 455, dtype: int64

# %%
df['Duration'].nunique()
# Out:
# 455

# %%
df['Duration'].min()
# Out:
# -2

# %%
df['Duration'].max()
# Out:
# 4881

# %%
#del df['Duration']

# %% [markdown]
# ### Destination

# %%
df['Destination'].nunique()
# Out:
# 149

# %% [markdown]
# Total 149 countries

# %%
df['Destination'].value_counts()[:3]
# Out:
# SINGAPORE    13255
# MALAYSIA      5930
# THAILAND      5894
# Name: Destination, dtype: int64

# %%
de1=df[df['Destination']=='SINGAPORE']
de1
# Out:
#       Agency Name Agency Type Distribution Channel        Product Name Claim  \
# 21            C2B    Airlines               Online         Bronze Plan    No
# 22            C2B    Airlines               Online         Bronze Plan    No
# 23            C2B    Airlines               Online         Bronze Plan   Yes
# 24            C2B    Airlines               Online         Silver Plan    No
# 25            C2B    Airlines               Online  Annual Silver Plan    No
# ...           ...         ...                  ...                 ...   ...
# 63309         SSI    Airlines               Online    Ticket Protector    No
# 63310         SSI    Airlines               Online    Ticket Protector    No
# 63311         SSI    Airlines               Online    Ticket Protector    No
# 63312         SSI    Airlines               Online    Ticket Protector    No
# 63313         SSI    Airlines               Online    Ticket Protector    No
#
# ...

# %%
de1['Agency Name'].value_counts()
# Out:
# C2B    8267
# EPX    3767
# SSI    1056
# TTW      73
# CWT      68
# ART      24
# Name: Agency Name, dtype: int64

# %% [markdown]
# More People choose to buy insurance from C2B agency while travelling to Singapore .

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Agency Name',data=de1,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Name', ylabel='count'>

# %% [markdown]
# Countplot on above information.

# %%
de2=df[df['Destination']=='MALAYSIA']
de2
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 0             CBH  Travel Agency              Offline
# 1             CBH  Travel Agency              Offline
# 11            JZI       Airlines               Online
# 13            CWT  Travel Agency               Online
# 18            JZI       Airlines               Online
# ...           ...            ...                  ...
# 63275         EPX  Travel Agency               Online
# 63287         EPX  Travel Agency               Online
# 63300         EPX  Travel Agency               Online
# 63302         EPX  Travel Agency               Online
# 63323         JZI       Airlines               Online
#
#                           Product Name Claim  Duration Destination  Net Sales  \
# 0                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 11                          Basic Plan    No         1    MALAYSIA      -18.0
# ...

# %%
de2['Agency Name'].value_counts()[:3]
# Out:
# EPX    3369
# CWT    1452
# JZI     592
# Name: Agency Name, dtype: int64

# %% [markdown]
# EPX has its toppest sale from MALAYSIA.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Agency Name',data=de2,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Agency Name', ylabel='count'>

# %% [markdown]
# Graph On Above Information

# %%
de3=df[df['Destination']=='THAILAND']
de3
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 8             CWT  Travel Agency               Online
# 19            CWT  Travel Agency               Online
# 37            EPX  Travel Agency               Online
# 45            EPX  Travel Agency               Online
# 47            EPX  Travel Agency               Online
# ...           ...            ...                  ...
# 63252         EPX  Travel Agency               Online
# 63278         EPX  Travel Agency               Online
# 63281         EPX  Travel Agency               Online
# 63291         EPX  Travel Agency               Online
# 63314         JZI       Airlines               Online
#
#                           Product Name Claim  Duration Destination  Net Sales  \
# 8      Rental Vehicle Excess Insurance    No        57    THAILAND      -19.8
# 19     Rental Vehicle Excess Insurance    No        14    THAILAND      -69.3
# 37            2 way Comprehensive Plan    No        28    THAILAND       20.0
# ...

# %%
de3['Agency Name'].value_counts()
# Out:
# EPX    3563
# JZI     978
# CWT     787
# TST     279
# CCR     110
# LWC      53
# CBH      51
# ART      39
# CSR      33
# TTW       1
# Name: Agency Name, dtype: int64

# %% [markdown]
# Most People choose EPX to travel Thailand
# and Least People Choose TTW, CSR and so on ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency Name           63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df.head()
# Out:
#   Agency Name    Agency Type Distribution Channel  \
# 0         CBH  Travel Agency              Offline
# 1         CBH  Travel Agency              Offline
# 2         CWT  Travel Agency               Online
# 3         CWT  Travel Agency               Online
# 4         CWT  Travel Agency               Online
#
#                       Product Name Claim  Duration Destination  Net Sales  \
# 0               Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1               Comprehensive Plan    No       186    MALAYSIA      -29.0
# 2  Rental Vehicle Excess Insurance    No        65   AUSTRALIA      -49.5
# 3  Rental Vehicle Excess Insurance    No        60   AUSTRALIA      -39.6
# 4  Rental Vehicle Excess Insurance    No        79       ITALY      -19.8
#
#    Commision (in value) Gender  Age
# 0                  9.57      F   81
# 1                  9.57      F   71
# 2                 29.70    NaN   32
# 3                 23.76    NaN   32
# ...

# %% [markdown]
# ### Net Sales

# %%
df['Net Sales'].value_counts()
# Out:
# 20.00    5988
# 10.00    4748
# 22.00    2343
# 0.00     1884
# 18.00    1643
#          ...
# 53.21       1
# 62.30       1
# 2.32        1
# 8.30        1
# 12.62       1
# Name: Net Sales, Length: 1139, dtype: int64

# %%
df['Agency Name'].value_counts()[:3]
# Out:
# EPX    35119
# CWT     8580
# C2B     8267
# Name: Agency Name, dtype: int64

# %%
epx['Net Sales'].value_counts()
# Out:
#  20.0     5777
#  10.0     4748
#  80.0     1221
#  112.0     895
#  21.0      770
#           ...
# -71.0        1
# -43.0        1
#  173.0       1
#  188.0       1
# -90.0        1
# Name: Net Sales, Length: 214, dtype: int64

# %% [markdown]
# Top Net Sales of EPX Agency.

# %%
i1['Net Sales'].value_counts()
# Out:
#  216.00    564
#  16.00     442
#  13.50     340
#  27.00     309
#  252.85    300
#           ...
# -107.00      1
#  269.00      1
#  112.70      1
#  357.50      1
#  207.90      1
# Name: Net Sales, Length: 463, dtype: int64

# %% [markdown]
# Top Net Sales of CWB Agency.

# %%
df['Agency Name'].value_counts()
# Out:
# EPX    35119
# CWT     8580
# C2B     8267
# JZI     6329
# SSI     1056
# JWT      749
# RAB      725
# LWC      689
# TST      528
# KML      392
# ART      331
# CCR      194
# CBH      101
# TTW       98
# CSR       86
# ADM       82
# Name: Agency Name, dtype: int64

# %%
i2=df[df['Agency Name']=='CWT']
i2
# Out:
#       Agency Name    Agency Type Distribution Channel  \
# 2             CWT  Travel Agency               Online
# 3             CWT  Travel Agency               Online
# 4             CWT  Travel Agency               Online
# 6             CWT  Travel Agency               Online
# 7             CWT  Travel Agency               Online
# ...           ...            ...                  ...
# 63241         CWT  Travel Agency               Online
# 63242         CWT  Travel Agency               Online
# 63243         CWT  Travel Agency               Online
# 63244         CWT  Travel Agency               Online
# 63245         CWT  Travel Agency               Online
#
#                           Product Name Claim  Duration    Destination  \
# 2      Rental Vehicle Excess Insurance    No        65      AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No        60      AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No        79          ITALY
# ...

# %% [markdown]
# Stored CWT Agency in a Variable.

# %%
i2['Net Sales'].value_counts().iloc[:5]
# Out:
# 29.7    1318
# 39.6    1115
# 0.0      994
# 19.8     799
# 49.5     794
# Name: Net Sales, dtype: int64

# %% [markdown]
# Top Net Sales of CWT Agency.

# %% [markdown]
# ### Commision

# %%
epx['Commision (in value)'].value_counts()
# Out:
# 0.0    35119
# Name: Commision (in value), dtype: int64

# %% [markdown]
# Commision Recieved To EPX Agency.

# %%
i1['Commision (in value)'].value_counts()
# Out:
# 54.00     572
# 4.00      448
# 3.38      341
# 6.75      311
# 63.21     306
#          ...
# 17.15       1
# 59.50       1
# 79.75       1
# 101.13      1
# 43.06       1
# Name: Commision (in value), Length: 433, dtype: int64

# %% [markdown]
# Commision Recieved To CWB Agency.

# %%
i2['Commision (in value)'].value_counts()
# Out:
# 17.82     1546
# 23.76     1307
# 11.88      976
# 29.70      922
# 41.58      742
# 35.64      669
# 5.94       544
# 47.52      485
# 53.46      372
# 59.40      288
# 65.34      174
# 71.28      108
# 77.22       97
# 83.16       95
# 89.10       73
# 95.04       42
# 100.98      26
# 106.92      22
# 118.80      17
# 112.86      17
# 124.74      14
# 166.32       9
# 130.68       8
# 136.62       8
# 148.50       6
# 172.26       3
# 160.38       3
# 142.56       2
# 154.44       2
# 178.20       2
# 184.14       1
# Name: Commision (in value), dtype: int64

# %% [markdown]
# Commision Recieved To CWT Agency.

# %% [markdown]
# ### Gender

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# M    9347
# F    8872
# Name: Gender, dtype: int64

# %%
df['Gender'].isnull().value_counts()
# Out:
# True     45107
# False    18219
# Name: Gender, dtype: int64

# %% [markdown]
# Gender Column  has Maximum Null Values.

# %%
df['Gender'].describe()
# Out:
# count     18219
# unique        2
# top           M
# freq       9347
# Name: Gender, dtype: object

# %%
df['Gender'].fillna(0)
# Out:
# 0        F
# 1        F
# 2        0
# 3        0
# 4        0
#         ..
# 63321    M
# 63322    F
# 63323    M
# 63324    M
# 63325    F
# Name: Gender, Length: 63326, dtype: object

# %% [markdown]
# Converting Null values of column Gender to Zero.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Gender',data=df,palette='ocean')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Female and Male Countplot.

# %%
df['Age'].nunique()
# Out:
# 89

# %%
age1=df['Age'].value_counts().iloc[:10]
age1
# Out:
# 36    24142
# 31     2663
# 48     2405
# 35     2348
# 30     1341
# 28     1255
# 29     1223
# 33     1112
# 32     1082
# 27     1065
# Name: Age, dtype: int64

# %% [markdown]
# People of Age Group 30-50 are buying maximum insurance.

# %%
plt.figure(figsize=(25,7))
sns.countplot(x='Age',data=df,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# We can clearly see that people of age 36 are buying maximum insurance.
# Age 36 is the age at which people get maximum life experiences and get many responsibilities and because of that they buy insurance.

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No null values present in Age column.

# %% [markdown]
# ###    Conclusion
